# %%
import sys
sys.path.append('../utils')
from eval import *

# %%
BASE_RES = 16
BATCH_SIZE = 1
SRC = '../../experiments'
SRC = "/home/nmaruani/Pi3olo/checkpoints/FINAL_EXP/experiments_12_11"

# %%
with torch.no_grad():
    GX = compute_all_generations("canyon", SRC, BASE_RES, 4, eval_batch_size=BATCH_SIZE, ddim_steps=100, verbose=True)
# Out:
# using ddim
# sampling loop time step:  89%|████████▉ | 8/9 [00:00<00:00, 166.61it/s]
# LEVEL 0: 0.05330491065979004
# sampling loop time step:  50%|█████     | 1/2 [00:00<00:00, 77.05it/s]
# LEVEL 1: 0.02420949935913086
# sampling loop time step:  50%|█████     | 1/2 [00:00<00:00, 82.57it/s]
# LEVEL 2: 0.023899555206298828
# sampling loop time step:  50%|█████     | 1/2 [00:00<00:00, 51.53it/s]
# LEVEL 3: 0.031227827072143555
# sampling loop time step:  50%|█████     | 1/2 [00:00<00:00, 16.18it/s]
# LEVEL 4: 0.07358145713806152

# %%
ind=0
tens = GX[-1]
disp_d = DiffusionTensor(tens.grid[ind], tens.data[ind]).remove_mask()
disp_d.get_global().colored_PC(.07)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(7.1227550…
